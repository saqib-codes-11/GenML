# %%
import pandas as pd
data = pd.read_csv("/Users/hemuram/Desktop/EECS/mlGeniusProject/data.csv")


import matplotlib.pyplot as plt

# %%
list(data)
# Out:
# ['Unnamed: 0',
#  'Accepted_Annotations',
#  'Annotation_Count',
#  'Annotation_Is_Verified',
#  'Artist',
#  'Classification',
#  'Comment_Count',
#  'Featured_Video',
#  'Followers',
#  'Genius_IQ',
#  'Hot',
#  'Is_Description',
#  'Is_Verified',
#  'Length_Referent_Text',
#  'Meme_Verified',
#  'Number_Contributors',
#  'Number_Verified_Annotations',
#  'Page_Views',
#  'Pinned',
#  'Pyong_Count',
#  'Referent_ID',
#  'Release_Date',
#  'Song_Title',
#  'Total_Votes']

# %%
import seaborn as sns
#numerical outputs
data_numerical = data[['Accepted_Annotations',
 'Annotation_Count',
 'Annotation_Is_Verified',
 'Artist',
 'Classification',
 'Comment_Count',
 'Featured_Video',
 'Followers',
 'Genius_IQ',
 'Is_Verified',
 'Length_Referent_Text',
 'Meme_Verified',
 'Number_Contributors',
 'Number_Verified_Annotations',
 'Page_Views',
 'Pinned',
 'Pyong_Count',
 'Referent_ID',
 'Release_Date',
 'Song_Title',
 'Total_Votes']]
data_numerical.head()
data_corr = data_numerical.corr()

# plot the heatmap and annotation on it

plt.figure(figsize=(20,10))
sns.heatmap(data_corr, xticklabels=data_corr.columns, yticklabels=data_corr.columns, annot=True)

# %% [markdown]
# # Decision Tree

# %%
from sklearn import tree
from sklearn.cross_validation import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
# Out:
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
train.head()
# Out:
#    Accepted_Annotations  Annotation_Count  Annotation_Is_Verified  \
# 0                    54                58                   False
# 1                    26                35                   False
# 2                    18                19                   False
# 3                    24                27                   False
# 4                    29                32                   False
#
#   Classification  Comment_Count  Featured_Video  Followers Genius_IQ    Hot  \
# 0       accepted              0           False        693         ?  False
# 1     unreviewed              0           False        598         ?  False
# 2       accepted              0           False       8610         ?  False
# 3       accepted              0           False        693         ?  False
# 4       accepted              0            True      17568    144243  False
#
#    Is_Description  ...    Length_Referent_Text  Meme_Verified  \
# ...

# %%
#splitting X and Y 
X = train.values[:,0:19]
Y = train.values[:,20]

# %%
clf_gini = DecisionTreeClassifier(criterion = "gini", random_state = 100,
                               max_depth=3, min_samples_leaf=5)

# %%
def writet_to_csv(data):
    df = pandas.DataFrame(data)
    df.to_csv('./test.csv')

# %%
import pandas

writet_to_csv(train)
